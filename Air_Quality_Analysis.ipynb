# %% [markdown]
# # Air Quality Analysis
#
# ### Data Description
#
# All of this data comes from EPA’s Air Quality System (AQS). Data collection agencies report their data to EPA via this system and it calculates several types of aggregate (summary) data for EPA internal use. This includes daily and annual summaries, but not monthly summaries, as these are not routinely needed by EPA. More details can be found at [here](https://aqs.epa.gov/aqsweb/airdata/FileFormats.html)
#
# Refer to the field descriptions at https://github.com/colaberry/hackathons/blob/master/data/aq_field_descriptions.csv
#
#
# ### What you will learn?
#
# The goals of this course are:
# 1. Ingest the data and extract relevant insights through analytical and statistical methods
# 2. Storytell the reports that is understandable to all kinds of audience
# 3. Perform clustering on the dataset to group data based on air quality.
#
#
# ### Case Study
#
# Assume that you are hired as a data scientist by a reputed Environmental Science Organisation. Congratulations!
# Now, that you are a data scientist it is expected that you study Air Quality and present Exploratory Data Analysis to the principle Data Scientist and the fellow enviroment evangelists.
#
# The following exercises will guide you presenting the report. All the best!
#
# ### Reading into a Dataframe
#
# The word dataframe is simply a data represented in a frame. And, yeah you guessed it right. Its a tabular format of representation of data. Usually they are represented in rows and columns. The library pandas allows us to read data and impute it in the form of dataframes. With pandas you can read a  **csv, excel, json** and bunch of other supported formats.
#
#
# **Syntax to read a csv file**
#
#     import pandas as pd
#     dataframe = pd.read_csv("DIRECTORY_TO_YOUR_FILE / URL")
#
#  **Syntax to check head and shape of a dataframe**
#
#     dataframe.head()
#     dataframe.shape()
#
# #### Exercise 1
#
# 1. Read the csv file in `air_data` variable
# 2. Assign and print variable `dimension` to the `.shape()` of the data
# 3. Assign and check variable - `air_data_sample` with the `.head()` of dataframe

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/colaberry/data/master/8hour_42101_2017_10K.csv"

# Write your code below

# %% [markdown]
# #### Hint
#
# Make sure that your varible is `air_data` and is read from `url` as explained in syntax.

# %%
air_data = pd.read_csv(url)
dimension = air_data.shape 
print (dimension)
air_data_sample = air_data.head()
air_data_sample
# Out:
# (9999, 23)
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42101    2  33.553056
# 1           1           73        23           42101    2  33.553056
# 2           1           73        23           42101    2  33.553056
# 3           1           73        23           42101    2  33.553056
# 4           1           73        23           42101    2  33.553056
#
#    Longitude  Datum   Parameter Name  Date Local         ...           \
# 0    -86.815  WGS84  Carbon monoxide  2017-01-01         ...
# 1    -86.815  WGS84  Carbon monoxide  2017-01-01         ...
# 2    -86.815  WGS84  Carbon monoxide  2017-01-01         ...
# 3    -86.815  WGS84  Carbon monoxide  2017-01-01         ...
# 4    -86.815  WGS84  Carbon monoxide  2017-01-01         ...
#
#          Sample Duration Pollutant Standard   Units of Measure  \
# 0  8-HR RUN AVG END HOUR     CO 8-hour 1971  Parts per million
# ...

# %%
#this is assertion block which verifies the solution.

try:
    def verify_answer():
        if air_data_sample.shape == (5, 23):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Exploratory Data Analysis
#
# The Exploratory Data Analysis a.k.a   **EDA**   is one of the most crucial parts of data science study. Before we dive deep into the data its always a good habit to do a surface study. Let's go through the description.csv file provided. Incase you missed it from Data Description its linked again [here](https://github.com/colaberry/hackathons/blob/master/data/aq_field_descriptions.csv)
#
# The facts to carry by on this datasets after reading the description are as follows:
#
# 1. The data is captured by sensors on 8-Hour basis
# 2. There are many types of data. Alike, numerical, floats, strings and object types too
#
# Let's dive into the EDA analysis.
#
# In real world data are always raw and unfiltered. Plus, there can be missing values sometimes in the dataset due to explanable or unexplanable circumstances. For starters lets start by testing if there are any missing values or not.
#
# ## Inspecting Missing Values
#
# The holy grail for the data visualizations in python are `matplotlib` and `seaborn`. We will import these for you.
#
#  **Syntax to import libraries**
#
#
#     import matplotlib.pyplot as plt
#     import seaborn as sns
#     %matplotlib inline
#
#
# *Note: In the notebook environment we add a line **%matplotlib inline** just so that the plots execute in the notebook cell structure*
#
#  **Syntax to check Null/NaN values**
#
#     df.isnull()
#     df.isnull().sum()   #Sum of all Nulls
#
# **Syntax for plotting heatmaps**
#
#     sns.heatmap(is_null_dataframe)
#
#
#
# #### Exercise
#
# 1. Assign variable `total_nulls` and print to the check total number nulls

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


# Write your code here
total_nulls = air_data.isnull().sum()
print (total_nulls)
# Out:
# State Code                         0
# County Code                        0
# Site Num                           0
# Parameter Code                     0
# POC                                0
# Latitude                           0
# Longitude                          0
# Datum                              0
# Parameter Name                     0
# Date Local                         0
# Time Local                         0
# Date GMT                           0
# Time GMT                           0
# Sample Duration                    0
# Pollutant Standard                 0
# Units of Measure                   0
# Observation Count                  0
# Observations with Events           0
# Null Observations                  0
# Mean Including All Data            0
# Mean Excluding All Flagged Data    0
# Mean Excluding Concurred Flags     0
# Date of Last Change                0
# dtype: int64

# %% [markdown]
# #### Hint
#
# Make sure that your varible is `total_nulls` and you adhere to the syntax.

# %%
total_nulls = air_data.isnull().sum()
print (total_nulls)
# Out:
# State Code                         0
# County Code                        0
# Site Num                           0
# Parameter Code                     0
# POC                                0
# Latitude                           0
# Longitude                          0
# Datum                              0
# Parameter Name                     0
# Date Local                         0
# Time Local                         0
# Date GMT                           0
# Time GMT                           0
# Sample Duration                    0
# Pollutant Standard                 0
# Units of Measure                   0
# Observation Count                  0
# Observations with Events           0
# Null Observations                  0
# Mean Including All Data            0
# Mean Excluding All Flagged Data    0
# Mean Excluding Concurred Flags     0
# Date of Last Change                0
# dtype: int64

# %%
try:
    def verify_answer():
        if total_nulls.shape == air_data.isnull().sum().shape:
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# Well, Did you get **Zero** nulls in all the columns ? Hmm! If you have read the description well then you might have sensed somehthing fishy!
#
# ## Re-Inspecting Missing Values via Null Observation Column
#
# The data is averaged for 8 hours and math says that 0s or Nulls if there any are averaged out too. Plus, there is a column in our dataset that clearly reads
#
#     Null Observations : The number of observations (samples) during the 8-hour period that were missed (and reported as Null by the data submitter)
#
# Let's check on this tricky feature as well as plot it with barplots
#
#  **Syntax to make a dataframe of value_counts for a column**
#
#     df['NAME OF THE COLUMN'].value_counts()
#
#     value_count_df = pd.DataFrame(df['NAME OF THE COLUMN'].value_counts())
#
# **Syntax for plotting barplots via valuecounts dataframe**
#
#     sns.barplot(value_count_df)
#
#
#
# #### Exercise 3
#
# 1. Assign variable `null_value_count_df` and print to the check value counts
# 2. Plot a barplot and assign it to `value_count_df_bar_plot` that shows well NaN counts

# %%
plt.figure(figsize=(10,6))
null_value_count_df = pd.DataFrame(air_data['Null Observations'].value_counts())
print (null_value_count_df)
# value_count_df_bar_plot =
# Out:
#    Null Observations
# 0               8049
# 2               1136
# 1                814

# %% [markdown]
# #### Hint
# Make sure you are adhered to the syntax and have read the documentation of seaborn barplots.

# %%
plt.figure(figsize=(10,6))
null_value_count_df = pd.DataFrame(air_data['Null Observations'].value_counts())
print (null_value_count_df)
value_count_df_bar_plot = sns.barplot(x=null_value_count_df.index, y='Null Observations', data=null_value_count_df)
# Out:
#    Null Observations
# 0               8049
# 2               1136
# 1                814

# %%
try:
    def verify_answer():
        if null_value_count_df.shape == (3,1):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# Now we see that there are **814** instances where we have 1 missing value from the sensors and **1136** instancs where we got 2 missing values per 8 hour duration.
#
# Lets check out the instances where we got these missing observations. Now, use the pandas conditional statements to filter out the instances where there are greater than **0** in Null Observation Column.
#
#
#  **Syntax to extract conditional instances **
#
#     df[(condition)]
#
#     condition = df['COLUMN'] > 0
#
#
#
# #### Exercise 4
#
# 1. Assign variable `null_events` and check the head of the null observations greater than 0

# %%
# null_events =

# %% [markdown]
# #### Hint
#
# Its tricky at first but gets habituated. Refer to the pandas documentations if you have trouble. Follow the syntax in one line

# %%
null_events =air_data[air_data['Null Observations']>0]
null_events.head()
# Out:
#     State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 75           1           73        23           42101    2  33.553056
# 76           1           73        23           42101    2  33.553056
# 77           1           73        23           42101    2  33.553056
# 78           1           73        23           42101    2  33.553056
# 81           1           73        23           42101    2  33.553056
#
#     Longitude  Datum   Parameter Name  Date Local         ...           \
# 75    -86.815  WGS84  Carbon monoxide  2017-01-04         ...
# 76    -86.815  WGS84  Carbon monoxide  2017-01-04         ...
# 77    -86.815  WGS84  Carbon monoxide  2017-01-04         ...
# 78    -86.815  WGS84  Carbon monoxide  2017-01-04         ...
# 81    -86.815  WGS84  Carbon monoxide  2017-01-05         ...
#
#           Sample Duration Pollutant Standard   Units of Measure  \
# 75  8-HR RUN AVG END HOUR     CO 8-hour 1971  Parts per million
# ...

# %%
try:
    def verify_answer():
        if null_events.shape == (1950, 23):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ### Feature Engineering and Extraction
#
# Cool! We shall continue the analysis of this later on to solve questions like;
#
# 1. Which hour/month/date has the maximum of Null observations?
# 2. The Disctribution of all numeric varibales across the time series.
# 3. How the mean is changing from pure to null observations?
#
# We do have the right information in our dataframe. All we need to do is extract these informations and make new columns for date,hour,year, day of week features.
#
# Lets do this!
#
#
# Pandas allow us a method pd.to_datetime() which eases the way to parse date-time information.
#
#  **Steps to parse date-time information**
#
#    1. First we convert the present column from object type to date-time object.
#    2. Then we use pandas to extact the particular date-time information.
#
# **Syntax**
#
#       df['DATECOLUMN(OBJECT TYPE)'] = df['DATECOLUMN(OBJECT TYPE)'].to_datetime()
#       df['DATECOLUMN(OBJECT TYPE)'] = df['DATECOLUMN(OBJECT TYPE)'].to_datetime()
#
#  #### Exercise 5
#
# 1. Introduce new Date-Time features namely - `year`,`month`,`day_of_month`,`day_of_week`,`hour`

# %%
air_data['Date Local'] = pd.to_datetime(air_data['Date Local'])
air_data['Hour Local'] = pd.to_datetime(air_data['Time Local']).dt.hour
air_data['Date GMT'] = pd.to_datetime(air_data['Date GMT'])
air_data['Hour GMT'] = pd.to_datetime(air_data['Time GMT']).dt.hour
air_data['Date of Last Change'] = pd.to_datetime(air_data['Date of Last Change'])
air_data[['Time Local','Date GMT','Date Local','Time GMT','Date of Last Change']].head()


# Write code from here 
# air_data['DOM GMT'] = 
# air_data['Month GMT'] = 
# air_data['Year GMT'] = 
# air_data['DOW GMT'] = 

# air_data['LS Year'] = 
# air_data['LS Month'] = 
# air_data['LS DOM'] = 
# air_data['LS DOW'] =
# Out:
#   Time Local   Date GMT Date Local Time GMT Date of Last Change
# 0      05:00 2017-01-01 2017-01-01    11:00          2017-04-19
# 1      06:00 2017-01-01 2017-01-01    12:00          2017-04-19
# 2      07:00 2017-01-01 2017-01-01    13:00          2017-04-19
# 3      08:00 2017-01-01 2017-01-01    14:00          2017-04-19
# 4      09:00 2017-01-01 2017-01-01    15:00          2017-04-19

# %% [markdown]
# #### Hint:
#
# Refer the pandas [DatetimeIndex properties](https://pandas.pydata.org/pandas-docs/stable/api.html#datetimeindex). You can do it!

# %%
air_data['DOM GMT'] = air_data['Date GMT'].dt.day
air_data['Month GMT'] = air_data['Date GMT'].dt.month
air_data['Year GMT'] = air_data['Date GMT'].dt.year
air_data['DOW GMT'] = air_data['Date GMT'].dt.dayofweek

air_data['LS Year'] = air_data['Date of Last Change'].dt.year
air_data['LS Month'] = air_data['Date of Last Change'].dt.month
air_data['LS DOM'] = air_data['Date of Last Change'].dt.day
air_data['LS DOW'] = air_data['Date of Last Change'].dt.dayofweek

# %%
try:
    def verify_answer():
        if air_data.shape == (9999, 33):
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# # Advanced Exploratory Data Analysis
#
#
# That was just great! Now we have the date time properties to answer our questions -
#
# 1. Correlation Between the features
# 2. Distribution of numerical features
# 3. CountPlot of the categorical features
#
#
# #### Exercise 5
#
#    1. Plot and assign a heatmap to `corr_heatmap` that shows correlation among different features

# %%
plt.figure(figsize=(15,10))

# Write code here
# corr_heatmap=

# %% [markdown]
# #### Hint:
# Use .corr() along sns.heatmap() functions to plot the correlation plots. And .clustermap() for Cluster plot

# %%
plt.figure(figsize=(15,15))
corr_heatmap= sns.heatmap(air_data.corr(),square=True, annot=True, cmap='viridis')

# %%
try:
    def verify_answer():
        if 1:
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ### Here comes the more number of plots
#
# ### Exercise
#
#   1. Plot and assign variable `distribution_plot` to distribution plots of numerical features in the following for loop with green color

# %%
numeric_data_cols = air_data._get_numeric_data().columns
plt.figure(figsize=(30,85))
# for i, c in enumerate(numeric_data_cols):
#     ax = plt.subplot(20,2,i+1)
#     ax.spines["top"].set_visible(False)
#     ax.spines["right"].set_visible(False)
#     distribution_plot =

# %% [markdown]
# #### Hint
# Understand the multi-axes plot above and use distplot for the iterating variable `c`

# %%
numeric_data_cols = air_data._get_numeric_data().columns
plt.figure(figsize=(30,85))
for i, c in enumerate(numeric_data_cols):
    ax = plt.subplot(20,2,i+1)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    distribution_plot = sns.distplot(air_data[c], color='g')
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/nonparametric/kde.py:494: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X,a,b,gridsize)/(delta*nobs)
# /usr/local/lib/python3.5/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
try:
    def verify_answer():
        if len(numeric_data_cols) == 23:
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
#  Similarly plot a `count_plot` of the categorical features

# %%
obj_data_cols = air_data.loc[:, air_data.dtypes == object].columns
plt.figure(figsize=(15,20))
for i, c in enumerate(obj_data_cols):
    ax = plt.subplot(5,2,i+1)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
#     count_plot =

# %% [markdown]
# #### Hint
# Understand the multi-axes plot above and use count for the iterating variable `c`

# %%
plt.figure(figsize=(15,20))
for i, c in enumerate(obj_data_cols):
    ax = plt.subplot(5,2,i+1)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    count_plot = sns.countplot(air_data[c])

# %%
try:
    def verify_answer():
        if len(obj_data_cols) == 7:
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ## Time Series Plots
#
# The time conveys lot of helpful insights in understanding the scenario from the data. Lets investigate the following below.
#
# 1. Which hour/month/date has the maximum of Null observations?
# 2. The Disctribution of all numeric varibales across the time series.
# 3. How the mean is changing from pure to null observations?
#
#
#
# ### Exercise
#
#   1. Plot a pivot heatmap with values to `Obersavation Count` and assign it to `pivot_hour_dom`

# %%
null_events =air_data[air_data['Null Observations']>0]
plt.figure(figsize=(17,10))
# plt.title('Observations Counts on Hour GMT vs. Day Of Month', fontsize=25)
# # pivot_hour_dom =

# %% [markdown]
# ### Hint
#
# Refer the title for the plot. It says all :)

# %%
null_events =air_data[air_data['Null Observations']>0]
plt.figure(figsize=(17,10))
plt.title('Observations Counts on Hour GMT vs. Day Of Month', fontsize=25)
pivot_hour_dom = sns.heatmap(air_data.pivot_table(values='Observation Count',index='DOM GMT', columns='Hour GMT') , cmap='inferno')

# %%
try:
    def verify_answer():
        if null_events.shape == (1950, 33) :
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# Great!
# As you can clearly see in the above heatmapThe hours 0-5 GMT are busy as well as 15-23 hours of day have significant observations. This clearly signifies the traffic hours in the city. Our plots depicted the same.
#
#
# ### Exercise
#
#   1. Similarly, plot a pivot heatmap with values to `Obersavation Count` and assign it to `pivot_hour_dow`

# %%
plt.figure(figsize=(17,10))
plt.figure(figsize=(17,10))
# pivot_hour_dow =

# %% [markdown]
# #### Hint
#
# Refer the plt.title to get idea about the index and column values

# %%
plt.figure(figsize=(17,10))
pivot_hour_dow = sns.heatmap(air_data.pivot_table(values='Observation Count',
                                columns='DOW GMT', index='Hour GMT') , cmap='viridis')

# %%
try:
    def verify_answer():
        if null_events.shape == (1950, 33) :
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# Another illustrative heatmap shows that 5-6 that is Saturday and Sunday are the heavist observants of Air Quality. Especially from 0 - 5 hours. That's all for EDA. Now lets explore the machine learning model on this amazing dataset
#
# ### Behind the scene EDA
#
# There was many minute EDA done on the data which showed various joinplots, boxplots for categories. The geoplot latitude only had 3 unique values. Hence, it was dumped in the favour of less quantifiable data.
#
# **Amazing facts found**
#
# 1. The exact position of the sensor were located at (by using latitude, longitude data) -  **2600 31st Ave N, Birmingham, AL 35207, USA**
# 2. The Night time pollution remains consitent whole week. Are night out parties is a great factor of pollution? May be
#
#
# # K-Means Unsupervised Model
#
# Now that we have done EDA. We are pretty much drawing conclusion on the data. We also saw that we are having columns that have only one unique value. Before we feed the model with the data lets make all the data machine learning ready.
#
#
# ### Exercise
#
# 1. Drop the columns which have only one unique value.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from scipy.spatial.distance import cdist
import numpy as np

cols_to_drop = ['Time GMT','State Code', 'County Code', 'LS Year', 'Parameter Code', 'Year GMT',
       'Observations with Events', 'Units of Measure', 'Datum',
       'Parameter Name', 'Pollutant Standard', 'Sample Duration','Date Local','Time Local','Date GMT','Date of Last Change']


X = air_data.drop(cols_to_drop, axis=1)

# %% [markdown]
# #### Hint
#
# Use .drop(columns, axis=1)

# %%
X = air_data.drop(cols_to_drop, axis=1)

# %%
try:
    def verify_answer():
        if X.shape == (9999, 17) :
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# ## How many number of clusters? How to decide ?
#
# As unsupervised models dont have a metric as true labels are absent. We often wonder what should be the actual k values.
#
# There are two methods to determine the optimum k clusters:
#
#
# ### 1. Elbow Method
#
#
# Here comes the famous **Elbow Method** to rescue us. The optimal value of the k clusters can be determined by calculating the distortions
#
# This method looks at the percentage of variance explained as a function of the number of clusters: One should choose a number of clusters so that adding another cluster doesn't give much better modeling of the data. More precisely, if one plots the percentage of variance explained by the clusters against the number of clusters, the first clusters will add much information (explain a lot of variance), but at some point the marginal gain will drop, giving an angle in the graph. The number of clusters is chosen at this point, hence the "elbow criterion".
#
# ![Elbow](https://pythonpro-9329.kxcdn.com/wp-content/uploads/2017/07/elbow-method.png)
#
#
#
# ### 2. Silhouette Scores
#
# The Silhouette Coefficient is a metric to estimate the optimum number of clusters. It uses average intra-cluster distance and average nearest-cluster distance for each sample. Higher the value of the score, the better the estimate. Typically the silhoutte scores go high and then fall peaking at an optimum cluster number. The values lie between -1.0 and 1.0.
#
# Silhouette coefficients (as these values are referred to as) near +1 indicate that the sample is far away from the neighboring clusters. A value of 0 indicates that the sample is on or very close to the decision boundary between two neighboring clusters and negative values indicate that those samples might have been assigned to the wrong cluster.
#
#
#
# ### Exercise
#
# 1. Plot the elbow plot and find the optimum `k` and assign `k` with the optimum value

# %%
# k means determine k
distortions = []
K = range(1,6)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(X)
    kmeanModel.fit(X)
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])
    
# Plot the elbow - clusters vs. distortions
plt.figure(figsize=(10,6))
plt.plot(K, distortions, 'bx-', color='gold')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

k = 3 # from the elbow graph

# %% [markdown]
# #### Hint
# Plot a graph `k` values as x and y as `distortions`

# %%
plt.figure(figsize=(10,6))
plt.plot(K, distortions, 'bx-', color='gold')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

k = 3 # from the elbow graph

# %%
try:
    def verify_answer():
        if k == 3 :
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# #### Exercise
#
# Similarly lets test the silhouette score, enter the optimal k value from Silhouette Score test. Assign `k2` with it

# %%
from sklearn.metrics import silhouette_score

k_clusters = []
sil_coeffecients = []

for n_cluster in range(2,6):
    kmeans = KMeans(n_clusters = n_cluster).fit(X)
    label = kmeans.labels_
    sil_coeff = silhouette_score(X, label)
    print("For n_clusters={}, Silhouette Coefficient = {}".format(n_cluster, sil_coeff))
    sil_coeffecients.append(sil_coeff)
    k_clusters.append(n_cluster)


sil_best = max(sil_coeffecients)
k_best_index = sil_coeffecients.index(sil_best)
k_best = k_clusters[k_best_index]
print("Optimum Number of Clusters:", k_best)

plt.figure(figsize=(10,6))
plt.plot(k_clusters, sil_coeffecients, color='r')
plt.ylabel('Silhouette Coefficient'), plt.xlabel('No. of Clusters')
plt.show()

k2 = 3
# Out:
# For n_clusters=2, Silhouette Coefficient = 0.7379370947251022
# For n_clusters=3, Silhouette Coefficient = 0.9793036591213978
# For n_clusters=4, Silhouette Coefficient = 0.6520264256008678
# For n_clusters=5, Silhouette Coefficient = 0.42709239944644206
# Optimum Number of Clusters: 3

# %% [markdown]
# #### Hint
#
# The first highest value is the optimal k value.

# %%
k2 = 3

# %%
try:
    def verify_answer():
        if k2 == 3 :
            return True
        else:
            return False

    ref_assert_var = verify_answer()
except Exception as e: 
    print('Your assertion block throws error: ' + str(e))
else:
    if ref_assert_var:
        print('continue')
    else:
        print('The answer did not pass the test.')
# Out:
# continue

# %% [markdown]
# That's all budding data scientist!
#
# Here's the Summary of what we covered.
#
# We learnt how to EDA a dataset which has numerous data types. And know how to find the replacement missing values if any. The correlation plot showed us multicollinearity, heatmaps showed us the distribution for days of month and day of week. Finally, we loaded a basic Kmeans model and trained on dataset. We were in dilemma to decide `k` and hence we went with **Elbow method** and **Silhouette Coefficient**.
#
# Though we arent certain about the true_labels. With our analysis we can assume that these sensors are placed - in 3 different areas, which is confirmed by 3 unique lat,long values. May be Urban, Rural and Greeny Areas.
#
#
#
# ##  Bonus Section: Visualizing the Clusters with PCA
#
# Principal component analysis (PCA) is a statistical procedure that uses an orthogonal transformation to convert a set of observations of possibly correlated variables into a set of values of linearly uncorrelated variables called principal components. The number of distinct principal components is equal to the smaller of the number of original variables or the number of observations minus one. This transformation is defined in such a way that the first principal component has the largest possible variance (that is, accounts for as much of the variability in the data as possible), and each succeeding component in turn has the highest variance possible under the constraint that it is orthogonal to the preceding components. The resulting vectors are an uncorrelated orthogonal basis set. PCA is sensitive to the relative scaling of the original variables.
#
# ![PCA](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f5/GaussianScatterPCA.svg/440px-GaussianScatterPCA.svg.png)
#
# Source - Wikipedia

# %%
from sklearn.decomposition import PCA as sklearnPCA
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
cluster = kmeans.predict(X)
sklearn_pca = sklearnPCA(n_components=3)
X_reduced  = sklearn_pca.fit_transform(X)
Y= cluster
c_map = {0:'b', 1:'r', 2:'g'}
from mpl_toolkits.mplot3d import Axes3D
plt.clf()
fig = plt.figure(6, figsize=(10,9))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(X_reduced[:, 0], X_reduced[:, 1], X_reduced[:, 2], s=1, c=[c_map[_] for _ in cluster] )
ax.set_title("First three PCA directions")
ax.set_xlabel("1st eigenvector")
ax.w_xaxis.set_ticklabels([])
ax.set_ylabel("2nd eigenvector")
ax.w_yaxis.set_ticklabels([])
ax.set_zlabel("3rd eigenvector")
ax.w_zaxis.set_ticklabels([])
# Out:
# []

# %% [markdown]
# ### Hint:
# Just press the play

# %%
#play
